# %%
import pandas as pd
import requests
import json
import datetime as dt

# %%
# Save config information.
url = "https://api.the-odds-api.com/v3/odds/?"
key = "ee3dbfa00009d80ce0791275a27f603a"
sport = "baseball_mlb"

# %%
# Build partial query URL
ml_query_url = f"{url}apiKey={key}&sport={sport}&region=us"

# %%
ml_response = requests.get(ml_query_url).json()

# %%
ml_response
# Out:
# {'success': True,
#  'data': [{'sport_key': 'baseball_mlb',
#    'sport_nice': 'MLB',
#    'teams': ['Toronto Blue Jays', 'Washington Nationals'],
#    'commence_time': 1596139500,
#    'home_team': 'Toronto Blue Jays',
#    'sites': [{'site_key': 'betfair',
#      'site_nice': 'Betfair',
#      'last_update': 1596133574,
#      'odds': {'h2h': [1.7, 2.36], 'h2h_lay': [1.74, 2.44]}},
#     {'site_key': 'bovada',
#      'site_nice': 'Bovada',
#      'last_update': 1596133511,
#      'odds': {'h2h': [1.65, 2.35]}},
#     {'site_key': 'fanduel',
#      'site_nice': 'FanDuel',
#      'last_update': 1596133513,
#      'odds': {'h2h': [1.64, 2.36]}},
#     {'site_key': 'betonlineag',
#      'site_nice': 'BetOnline.ag',
#      'last_update': 1596133509,
#      'odds': {'h2h': [1.67, 2.37, 1.0]}},
#     {'site_key': 'pointsbetus',
#      'site_nice': 'PointsBet (US)',
#      'last_update': 1596133516,
#      'odds': {'h2h': [1.62, 2.35]}},
#     {'site_key': 'lowvig',
#      'site_nice': 'LowVig.ag',
#      'last_update': 1596133549,
#      'odds': {'h2h': [1.68, 2.37]}},
#     {'site_key': 'williamhill_us',
#      'site_nice': 'William Hill (US)',
#      'last_update': 1596133554,
#      'odds': {'h2h': [1.69, 2.35]}},
#     {'site_key': 'intertops',
#      'site_nice': 'Intertops',
#      'last_update': 1596133484,
#      'odds': {'h2h': [1.67, 2.35]}},
#     {'site_key': 'gtbets',
#      'site_nice': 'GTbets',
#      'last_update': 1596133511,
#      'odds': {'h2h': [1.69, 2.35]}},
#     {'site_key': 'betrivers',
#      'site_nice': 'BetRivers',
#      'last_update': 1596133532,
#      'odds': {'h2h': [1.64, 2.3]}},
#     {'site_key': 'unibet',
#      'site_nice': 'Unibet',
#      'last_update': 1596133533,
#      'odds': {'h2h': [1.64, 2.3]}},
#     {'site_key': 'draftkings',
#      'site_nice': 'DraftKings',
#      'last_update': 1596133543,
#      'odds': {'h2h': [1.64, 2.3]}}],
#    'sites_count': 12},
#   {'sport_key': 'baseball_mlb',
#    'sport_nice': 'MLB',
#    'teams': ['Chicago Cubs', 'Cincinnati Reds'],
#    'commence_time': 1596147000,
#    'home_team': 'Cincinnati Reds',
#    'sites': [{'site_key': 'bovada',
#      'site_nice': 'Bovada',
#      'last_update': 1596133511,
#      'odds': {'h2h': [1.94, 1.88]}},
#     {'site_key': 'betonlineag',
#      'site_nice': 'BetOnline.ag',
#      'last_update': 1596133509,
#      'odds': {'h2h': [2.0, 1.9, 1.0]}},
#     {'site_key': 'lowvig',
#      'site_nice': 'LowVig.ag',
#      'last_update': 1596133549,
#      'odds': {'h2h': [2.0, 1.91]}},
#     {'site_key': 'williamhill_us',
#      'site_nice': 'William Hill (US)',
#      'last_update': 1596133554,
#      'odds': {'h2h': [2.01, 1.9]}},
#     {'site_key': 'draftkings',
#      'site_nice': 'DraftKings',
#      'last_update': 1596133543,
#      'odds': {'h2h': [2.02, 1.82]}},
#     {'site_key': 'fanduel',
#      'site_nice': 'FanDuel',
#      'last_update': 1596133513,
#      'odds': {'h2h': [2.0, 1.88]}},
#     {'site_key': 'unibet',
#      'site_nice': 'Unibet',
#      'last_update': 1596133533,
#      'odds': {'h2h': [2.02, 1.82]}},
#     {'site_key': 'betrivers',
#      'site_nice': 'BetRivers',
#      'last_update': 1596133532,
#      'odds': {'h2h': [2.02, 1.82]}},
#     {'site_key': 'pointsbetus',
#      'site_nice': 'PointsBet (US)',
#      'last_update': 1596133516,
#      'odds': {'h2h': [1.95, 1.87]}},
#     {'site_key': 'gtbets',
#      'site_nice': 'GTbets',
#      'last_update': 1596133511,
#      'odds': {'h2h': [2.0, 1.91]}},
#     {'site_key': 'betfair',
#      'site_nice': 'Betfair',
#      'last_update': 1596133574,
#      'odds': {'h2h': [2.06, 1.89], 'h2h_lay': [2.14, 1.94]}},
#     {'site_key': 'intertops',
#      'site_nice': 'Intertops',
#      'last_update': 1596133484,
#      'odds': {'h2h': [2.05, 1.87]}}],
#    'sites_count': 12},
#   {'sport_key': 'baseball_mlb',
#    'sport_nice': 'MLB',
#    'teams': ['Baltimore Orioles', 'New York Yankees'],
#    'commence_time': 1596150300,
#    'home_team': 'Baltimore Orioles',
#    'sites': [{'site_key': 'betonlineag',
#      'site_nice': 'BetOnline.ag',
#      'last_update': 1596133509,
#      'odds': {'h2h': [3.16, 1.41, 1.0]}},
#     {'site_key': 'williamhill_us',
#      'site_nice': 'William Hill (US)',
#      'last_update': 1596133554,
#      'odds': {'h2h': [3.15, 1.41]}},
#     {'site_key': 'draftkings',
#      'site_nice': 'DraftKings',
#      'last_update': 1596133543,
#      'odds': {'h2h': [3.05, 1.41]}},
#     {'site_key': 'lowvig',
#      'site_nice': 'LowVig.ag',
#      'last_update': 1596133549,
#      'odds': {'h2h': [3.16, 1.42]}},
#     {'site_key': 'bovada',
#      'site_nice': 'Bovada',
#      'last_update': 1596133511,
#      'odds': {'h2h': [3.1, 1.4]}},
#     {'site_key': 'fanduel',
#      'site_nice': 'FanDuel',
#      'last_update': 1596133513,
#      'odds': {'h2h': [3.05, 1.42]}},
#     {'site_key': 'unibet',
#      'site_nice': 'Unibet',
#      'last_update': 1596133533,
#      'odds': {'h2h': [3.05, 1.38]}},
#     {'site_key': 'betrivers',
#      'site_nice': 'BetRivers',
#      'last_update': 1596133532,
#      'odds': {'h2h': [3.05, 1.41]}},
#     {'site_key': 'pointsbetus',
#      'site_nice': 'PointsBet (US)',
#      'last_update': 1596133516,
#      'odds': {'h2h': [3.05, 1.38]}},
#     {'site_key': 'gtbets',
#      'site_nice': 'GTbets',
#      'last_update': 1596133511,
#      'odds': {'h2h': [3.05, 1.43]}},
#     {'site_key': 'betfair',
#      'site_nice': 'Betfair',
#      'last_update': 1596133574,
#      'odds': {'h2h': [3.25, 1.42], 'h2h_lay': [3.4, 1.45]}},
#     {'site_key': 'intertops',
#      'site_nice': 'Intertops',
#      'last_update': 1596133484,
#      'odds': {'h2h': [3.1, 1.42]}}],
#    'sites_count': 12},
#   {'sport_key': 'baseball_mlb',
#    'sport_nice': 'MLB',
#    'teams': ['Cleveland Indians', 'Minnesota Twins'],
#    'commence_time': 1596150420,
#    'home_team': 'Minnesota Twins',
#    'sites': [{'site_key': 'bovada',
#      'site_nice': 'Bovada',
#      'last_update': 1596133511,
#      'odds': {'h2h': [1.96, 1.86]}},
#     {'site_key': 'betonlineag',
#      'site_nice': 'BetOnline.ag',
#      'last_update': 1596133509,
#      'odds': {'h2h': [2.02, 1.89, 1.0]}},
#     {'site_key': 'lowvig',
#      'site_nice': 'LowVig.ag',
#      'last_update': 1596133549,
#      'odds': {'h2h': [2.02, 1.89]}},
#     {'site_key': 'williamhill_us',
#      'site_nice': 'William Hill (US)',
#      'last_update': 1596133554,
#      'odds': {'h2h': [2.05, 1.87]}},
#     {'site_key': 'fanduel',
#      'site_nice': 'FanDuel',
#      'last_update': 1596133513,
#      'odds': {'h2h': [1.98, 1.89]}},
#     {'site_key': 'betrivers',
#      'site_nice': 'BetRivers',
#      'last_update': 1596133532,
#      'odds': {'h2h': [2.08, 1.8]}},
#     {'site_key': 'unibet',
#      'site_nice': 'Unibet',
#      'last_update': 1596133533,
#      'odds': {'h2h': [2.07, 1.79]}},
#     {'site_key': 'draftkings',
#      'site_nice': 'DraftKings',
#      'last_update': 1596133543,
#      'odds': {'h2h': [2.08, 1.8]}},
#     {'site_key': 'pointsbetus',
#      'site_nice': 'PointsBet (US)',
#      'last_update': 1596133516,
#      'odds': {'h2h': [2.0, 1.83]}},
#     {'site_key': 'gtbets',
#      'site_nice': 'GTbets',
#      'last_update': 1596133511,
#      'odds': {'h2h': [2.07, 1.85]}},
#     {'site_key': 'betfair',
#      'site_nice': 'Betfair',
#      'last_update': 1596133574,
#      'odds': {'h2h': [2.06, 1.87], 'h2h_lay': [2.16, 1.94]}},
#     {'site_key': 'intertops',
#      'site_nice': 'Intertops',
#      'last_update': 1596133484,
#      'odds': {'h2h': [2.05, 1.87]}}],
#    'sites_count': 12},
#   {'sport_key': 'baseball_mlb',
#    'sport_nice': 'MLB',
#    'teams': ['Boston Red Sox', 'New York Mets'],
#    'commence_time': 1596150420,
#    'home_team': 'New York Mets',
#    'sites': [{'site_key': 'betonlineag',
#      'site_nice': 'BetOnline.ag',
#      'last_update': 1596133509,
#      'odds': {'h2h': [2.37, 1.67, 1.0]}},
#     {'site_key': 'williamhill_us',
#      'site_nice': 'William Hill (US)',
#      'last_update': 1596133554,
#      'odds': {'h2h': [2.35, 1.69]}},
#     {'site_key': 'lowvig',
#      'site_nice': 'LowVig.ag',
#      'last_update': 1596133549,
#      'odds': {'h2h': [2.37, 1.68]}},
#     {'site_key': 'bovada',
#      'site_nice': 'Bovada',
#      'last_update': 1596133511,
#      'odds': {'h2h': [2.37, 1.64]}},
#     {'site_key': 'draftkings',
#      'site_nice': 'DraftKings',
#      'last_update': 1596133543,
#      'odds': {'h2h': [2.35, 1.64]}},
#     {'site_key': 'fanduel',
#      'site_nice': 'FanDuel',
#      'last_update': 1596133513,
#      'odds': {'h2h': [2.34, 1.65]}},
#     {'site_key': 'unibet',
#      'site_nice': 'Unibet',
#      'last_update': 1596133533,
#      'odds': {'h2h': [2.35, 1.6]}},
#     {'site_key': 'betrivers',
#      'site_nice': 'BetRivers',
#      'last_update': 1596133532,
#      'odds': {'h2h': [2.35, 1.64]}},
#     {'site_key': 'pointsbetus',
#      'site_nice': 'PointsBet (US)',
#      'last_update': 1596133516,
#      'odds': {'h2h': [2.35, 1.62]}},
#     {'site_key': 'gtbets',
#      'site_nice': 'GTbets',
#      'last_update': 1596133511,
#      'odds': {'h2h': [2.4, 1.67]}},
#     {'site_key': 'betfair',
#      'site_nice': 'Betfair',
#      'last_update': 1596133574,
#      'odds': {'h2h': [2.4, 1.68], 'h2h_lay': [2.48, 1.71]}},
#     {'site_key': 'intertops',
#      'site_nice': 'Intertops',
#      'last_update': 1596133484,
#      'odds': {'h2h': [2.35, 1.67]}}],
#    'sites_count': 12},
#   {'sport_key': 'baseball_mlb',
#    'sport_nice': 'MLB',
#    'teams': ['Detroit Tigers', 'Kansas City Royals'],
#    'commence_time': 1596150600,
#    'home_team': 'Detroit Tigers',
#    'sites': [{'site_key': 'betonlineag',
#      'site_nice': 'BetOnline.ag',
#      'last_update': 1596133509,
#      'odds': {'h2h': [2.24, 1.74, 1.0]}},
#     {'site_key': 'williamhill_us',
#      'site_nice': 'William Hill (US)',
#      'last_update': 1596133554,
#      'odds': {'h2h': [2.2, 1.77]}},
#     {'site_key': 'lowvig',
#      'site_nice': 'LowVig.ag',
#      'last_update': 1596133549,
#      'odds': {'h2h': [2.24, 1.75]}},
#     {'site_key': 'bovada',
#      'site_nice': 'Bovada',
#      'last_update': 1596133511,
#      'odds': {'h2h': [2.18, 1.73]}},
#     {'site_key': 'draftkings',
#      'site_nice': 'DraftKings',
#      'last_update': 1596133543,
#      'odds': {'h2h': [2.25, 1.7]}},
#     {'site_key': 'unibet',
#      'site_nice': 'Unibet',
#      'last_update': 1596133533,
#      'odds': {'h2h': [2.25, 1.65]}},
#     {'site_key': 'betrivers',
#      'site_nice': 'BetRivers',
#      'last_update': 1596133532,
#      'odds': {'h2h': [2.25, 1.7]}},
#     {'site_key': 'pointsbetus',
#      'site_nice': 'PointsBet (US)',
#      'last_update': 1596133516,
#      'odds': {'h2h': [2.15, 1.74]}},
#     {'site_key': 'fanduel',
#      'site_nice': 'FanDuel',
#      'last_update': 1596133513,
#      'odds': {'h2h': [2.16, 1.76]}},
#     {'site_key': 'gtbets',
#      'site_nice': 'GTbets',
#      'last_update': 1596133511,
#      'odds': {'h2h': [2.2, 1.77]}},
#     {'site_key': 'betfair',
#      'site_nice': 'Betfair',
#      'last_update': 1596133574,
#      'odds': {'h2h': [2.26, 1.77], 'h2h_lay': [2.3, 1.79]}},
#     {'site_key': 'intertops',
#      'site_nice': 'Intertops',
#      'last_update': 1596133484,
#      'odds': {'h2h': [2.25, 1.74]}}],
#    'sites_count': 12},
#   {'sport_key': 'baseball_mlb',
#    'sport_nice': 'MLB',
#    'teams': ['Atlanta Braves', 'Tampa Bay Rays'],
#    'commence_time': 1596150600,
#    'home_team': 'Atlanta Braves',
#    'sites': [{'site_key': 'lowvig',
#      'site_nice': 'LowVig.ag',
#      'last_update': 1596133549,
#      'odds': {'h2h': [1.69, 2.33]}},
#     {'site_key': 'betonlineag',
#      'site_nice': 'BetOnline.ag',
#      'last_update': 1596133509,
#      'odds': {'h2h': [1.69, 2.33, 1.0]}},
#     {'site_key': 'bovada',
#      'site_nice': 'Bovada',
#      'last_update': 1596133511,
#      'odds': {'h2h': [1.68, 2.27]}},
#     {'site_key': 'draftkings',
#      'site_nice': 'DraftKings',
#      'last_update': 1596133543,
#      'odds': {'h2h': [1.72, 2.2]}},
#     {'site_key': 'unibet',
#      'site_nice': 'Unibet',
#      'last_update': 1596133533,
#      'odds': {'h2h': [1.67, 2.2]}},
#     {'site_key': 'betrivers',
#      'site_nice': 'BetRivers',
#      'last_update': 1596133532,
#      'odds': {'h2h': [1.72, 2.2]}},
#     {'site_key': 'fanduel',
#      'site_nice': 'FanDuel',
#      'last_update': 1596133513,
#      'odds': {'h2h': [1.68, 2.28]}},
#     {'site_key': 'pointsbetus',
#      'site_nice': 'PointsBet (US)',
#      'last_update': 1596133516,
#      'odds': {'h2h': [1.67, 2.3]}},
#     {'site_key': 'williamhill_us',
#      'site_nice': 'William Hill (US)',
#      'last_update': 1596133554,
#      'odds': {'h2h': [1.69, 2.35]}},
#     {'site_key': 'gtbets',
#      'site_nice': 'GTbets',
#      'last_update': 1596133511,
#      'odds': {'h2h': [1.7, 2.32]}},
#     {'site_key': 'betfair',
#      'site_nice': 'Betfair',
#      'last_update': 1596133574,
#      'odds': {'h2h': [1.72, 2.3], 'h2h_lay': [1.77, 2.4]}},
#     {'site_key': 'intertops',
#      'site_nice': 'Intertops',
#      'last_update': 1596133484,
#      'odds': {'h2h': [1.69, 2.33]}}],
#    'sites_count': 12},
#   {'sport_key': 'baseball_mlb',
#    'sport_nice': 'MLB',
#    'teams': ['Arizona Diamondbacks', 'Los Angeles Dodgers'],
#    'commence_time': 1596159600,
#    'home_team': 'Arizona Diamondbacks',
#    'sites': [{'site_key': 'betonlineag',
#      'site_nice': 'BetOnline.ag',
#      'last_update': 1596133509,
#      'odds': {'h2h': [2.41, 1.65, 1.0]}},
#     {'site_key': 'lowvig',
#      'site_nice': 'LowVig.ag',
#      'last_update': 1596133549,
#      'odds': {'h2h': [2.41, 1.65]}},
#     {'site_key': 'williamhill_us',
#      'site_nice': 'William Hill (US)',
#      'last_update': 1596133554,
#      'odds': {'h2h': [2.47, 1.64]}},
#     {'site_key': 'fanduel',
#      'site_nice': 'FanDuel',
#      'last_update': 1596133513,
#      'odds': {'h2h': [2.36, 1.64]}},
#     {'site_key': 'bovada',
#      'site_nice': 'Bovada',
#      'last_update': 1596133511,
#      'odds': {'h2h': [2.41, 1.62]}},
#     {'site_key': 'pointsbetus',
#      'site_nice': 'PointsBet (US)',
#      'last_update': 1596133516,
#      'odds': {'h2h': [2.4, 1.61]}},
#     {'site_key': 'unibet',
#      'site_nice': 'Unibet',
#      'last_update': 1596133533,
#      'odds': {'h2h': [2.35, 1.62]}},
#     {'site_key': 'betrivers',
#      'site_nice': 'BetRivers',
#      'last_update': 1596133532,
#      'odds': {'h2h': [2.35, 1.64]}},
#     {'site_key': 'draftkings',
#      'site_nice': 'DraftKings',
#      'last_update': 1596133543,
#      'odds': {'h2h': [2.35, 1.64]}},
#     {'site_key': 'gtbets',
#      'site_nice': 'GTbets',
#      'last_update': 1596133511,
#      'odds': {'h2h': [2.44, 1.65]}},
#     {'site_key': 'betfair',
#      'site_nice': 'Betfair',
#      'last_update': 1596133574,
#      'odds': {'h2h': [2.42, 1.65], 'h2h_lay': [2.54, 1.71]}}],
#    'sites_count': 11},
#   {'sport_key': 'baseball_mlb',
#    'sport_nice': 'MLB',
#    'teams': ['Los Angeles Angels', 'Seattle Mariners'],
#    'commence_time': 1596159600,
#    'home_team': 'Los Angeles Angels',
#    'sites': [{'site_key': 'draftkings',
#      'site_nice': 'DraftKings',
#      'last_update': 1596133543,
#      'odds': {'h2h': [1.45, 2.85]}},
#     {'site_key': 'lowvig',
#      'site_nice': 'LowVig.ag',
#      'last_update': 1596133549,
#      'odds': {'h2h': [1.53, 2.74]}},
#     {'site_key': 'williamhill_us',
#      'site_nice': 'William Hill (US)',
#      'last_update': 1596133554,
#      'odds': {'h2h': [1.51, 2.75]}},
#     {'site_key': 'betonlineag',
#      'site_nice': 'BetOnline.ag',
#      'last_update': 1596133509,
#      'odds': {'h2h': [1.52, 2.74, 1.0]}},
#     {'site_key': 'bovada',
#      'site_nice': 'Bovada',
#      'last_update': 1596133511,
#      'odds': {'h2h': [1.5, 2.7]}},
#     {'site_key': 'fanduel',
#      'site_nice': 'FanDuel',
#      'last_update': 1596133513,
#      'odds': {'h2h': [1.49, 2.76]}},
#     {'site_key': 'intertops',
#      'site_nice': 'Intertops',
#      'last_update': 1596133484,
#      'odds': {'h2h': [1.65, 2.4]}},
#     {'site_key': 'betfair',
#      'site_nice': 'Betfair',
#      'last_update': 1596133574,
#      'odds': {'h2h': [1.51, 2.8], 'h2h_lay': [1.56, 2.98]}},
#     {'site_key': 'unibet',
#      'site_nice': 'Unibet',
#      'last_update': 1596133533,
#      'odds': {'h2h': [1.45, 2.85]}},
#     {'site_key': 'betrivers',
#      'site_nice': 'BetRivers',
#      'last_update': 1596133532,
#      'odds': {'h2h': [1.45, 2.85]}},
#     {'site_key': 'pointsbetus',
#      'site_nice': 'PointsBet (US)',
#      'last_update': 1596133516,
#      'odds': {'h2h': [1.5, 2.7]}},
#     {'site_key': 'gtbets',
#      'site_nice': 'GTbets',
#      'last_update': 1596133511,
#      'odds': {'h2h': [1.53, 2.7]}}],
#    'sites_count': 12},
#   {'sport_key': 'baseball_mlb',
#    'sport_nice': 'MLB',
#    'teams': ['San Diego Padres', 'San Francisco Giants'],
#    'commence_time': 1596159900,
#    'home_team': 'San Francisco Giants',
#    'sites': [{'site_key': 'unibet',
#      'site_nice': 'Unibet',
#      'last_update': 1596133533,
#      'odds': {'h2h': [1.54, 2.55]}},
#     {'site_key': 'betfair',
#      'site_nice': 'Betfair',
#      'last_update': 1596133574,
#      'odds': {'h2h': [1.61, 2.58], 'h2h_lay': [1.63, 2.62]}},
#     {'site_key': 'bovada',
#      'site_nice': 'Bovada',
#      'last_update': 1596133511,
#      'odds': {'h2h': [1.57, 2.5]}},
#     {'site_key': 'betonlineag',
#      'site_nice': 'BetOnline.ag',
#      'last_update': 1596133509,
#      'odds': {'h2h': [1.6, 2.52, 1.0]}},
#     {'site_key': 'pointsbetus',
#      'site_nice': 'PointsBet (US)',
#      'last_update': 1596133516,
#      'odds': {'h2h': [1.56, 2.5]}},
#     {'site_key': 'draftkings',
#      'site_nice': 'DraftKings',
#      'last_update': 1596133543,
#      'odds': {'h2h': [1.55, 2.55]}},
#     {'site_key': 'lowvig',
#      'site_nice': 'LowVig.ag',
#      'last_update': 1596133549,
#      'odds': {'h2h': [1.6, 2.53]}},
#     {'site_key': 'betrivers',
#      'site_nice': 'BetRivers',
#      'last_update': 1596133532,
#      'odds': {'h2h': [1.55, 2.55]}},
#     {'site_key': 'williamhill_us',
#      'site_nice': 'William Hill (US)',
#      'last_update': 1596133554,
#      'odds': {'h2h': [1.58, 2.57]}},
#     {'site_key': 'intertops',
#      'site_nice': 'Intertops',
#      'last_update': 1596133484,
#      'odds': {'h2h': [1.57, 2.57]}},
#     {'site_key': 'gtbets',
#      'site_nice': 'GTbets',
#      'last_update': 1596133511,
#      'odds': {'h2h': [1.6, 2.52]}},
#     {'site_key': 'fanduel',
#      'site_nice': 'FanDuel',
#      'last_update': 1596133513,
#      'odds': {'h2h': [1.59, 2.48]}}],
#    'sites_count': 12}]}

# %%
# Build partial query URL
pl_query_url = f"{url}apiKey={key}&sport={sport}&region=us&mkt=spreads"

# %%
pl_response = requests.get(pl_query_url).json()

# %%
def pl_api(data):
    team = []
    home = []
    date = []
    pl = []
    home_odds = []
    away_odds = []
    odds = []
    
    for game in range(len(data['data'])):
        event = data['data'][game]
        team.append(event['teams'][0])
        team.append(event['teams'][1])
        home.append(1)
        home.append(0)
        time = dt.datetime.fromtimestamp(int(event['commence_time'])).strftime('%Y-%m-%d')
        date.append(time)
        date.append(time)
        home_odds = []
        away_odds = []
        for site in range(len(event['sites'])):
            h_odd = event['sites'][site]['odds']['spreads']['odds'][0]
            a_odd = event['sites'][site]['odds']['spreads']['odds'][1]    
            home_odds.append(h_odd)
            away_odds.append(a_odd)
        if event['sites_count'] == 0:
            odds.append('NaN')
            odds.append('NaN')
            pl.append('NaN')
            pl.append('NaN')
        else:
            h_odds = sum(home_odds)/len(home_odds)
            a_odds = sum(away_odds)/len(away_odds)
            if h_odds > 2:
                h_odds = round((h_odds - 1) * 100)
            elif h_odds == 1:
                h_odds = 'NaN'
            elif h_odds < 2:
                h_odds = round(100 / (1 - h_odds))
            else:
                h_odds = 100
            if a_odds > 2:
                a_odds = round((a_odds - 1) * 100)
            elif a_odds == 1:
                a_odds = 'NaN'
            elif a_odds < 2:
                a_odds = round(100 / (1 - a_odds))
            else:
                a_odds = 100
            odds.append(h_odds)
            odds.append(a_odds)
            pl.append(event['sites'][site]['odds']['spreads']['points'][0])
            pl.append(event['sites'][site]['odds']['spreads']['points'][1])
        
    game_dict = {
        "Team": team,
        "Date": date,
        "Home": home,
        "Puck Line": pl,
        "PL": odds
    }
    df = pd.DataFrame(game_dict)
    df = df.round({'Puck Line':1,'PL':0})
    return df

# %%
def ml_api(data):
    team = []
    home = []
    date = []
    home_odds = []
    away_odds = []
    odds = []
    
    for game in range(len(data['data'])):
        event = data['data'][game]
        team.append(event['teams'][0])
        team.append(event['teams'][1])
        home.append(1)
        home.append(0)
        time = dt.datetime.fromtimestamp(int(event['commence_time'])).strftime('%Y-%m-%d')
        date.append(time)
        date.append(time)
        home_odds = []
        away_odds = []
        for site in range(len(event['sites'])):
            h_odd = event['sites'][site]['odds']['h2h'][0]
            a_odd = event['sites'][site]['odds']['h2h'][1]  
            home_odds.append(h_odd)
            away_odds.append(a_odd)
        if event['sites_count'] == 0:
            odds.append('NaN')
            odds.append('NaN')
        else:
            h_odds = sum(home_odds)/len(home_odds)
            a_odds = sum(away_odds)/len(away_odds)
            if h_odds > 2:
                h_odds = round((h_odds - 1) * 100)
            elif h_odds == 1:
                h_odds = 'NaN'
            elif h_odds < 2:
                h_odds = round(100 / (1 - h_odds))
            else:
                h_odds = 100
            if a_odds > 2:
                a_odds = round((a_odds - 1) * 100)
            elif a_odds == 1:
                a_odds = 'NaN'
            elif a_odds < 2:
                a_odds = round(100 / (1 - a_odds))
            else:
                a_odds = 100
            odds.append(h_odds)
            odds.append(a_odds)
        
    game_dict = {
        "Team": team,
        "Date": date,
        "Home": home,
        "ML": odds
    }
    df = pd.DataFrame(game_dict)
    df = df.round({'ML':0})
    return df

# %%
ml_df = ml_api(ml_response)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-99-12a943e9da33> in <module>
# ----> 1 ml_df = ml_api(ml_response)
#
# NameError: name 'ml_response' is not defined

# %%
ml_df
# Out:
#                      Team        Date  Home     ML
# 0     Carolina Hurricanes  2020-08-01     1 -121.0
# 1        New York Rangers  2020-08-01     0  119.0
# 2      Chicago Blackhawks  2020-08-01     1  139.0
# 3         Edmonton Oilers  2020-08-01     0 -143.0
# 4        Florida Panthers  2020-08-01     1  103.0
# 5      New York Islanders  2020-08-01     0 -108.0
# 6      Montreal Canadiens  2020-08-01     1  174.0
# 7     Pittsburgh Penguins  2020-08-01     0 -120.0
# 8          Calgary Flames  2020-08-01     1 -111.0
# 9           Winnipeg Jets  2020-08-01     0  107.0
# 10        Arizona Coyotes  2020-08-02     1  114.0
# 11    Nashville Predators  2020-08-02     0 -117.0
# 12          Boston Bruins  2020-08-02     1 -140.0
# 13    Philadelphia Flyers  2020-08-02     0  111.0
# 14     Colorado Avalanche  2020-08-02     1  120.0
# 15         St Louis Blues  2020-08-02     0  125.0
# 16  Columbus Blue Jackets  2020-08-02     1  142.0
# 17    Toronto Maple Leafs  2020-08-02     0 -143.0
# 18         Minnesota Wild  2020-08-02     1  110.0
# 19      Vancouver Canucks  2020-08-02     0 -111.0
# 20    Tampa Bay Lightning  2020-08-03     1 -115.0
# 21    Washington Capitals  2020-08-03     0  116.0
# 22           Dallas Stars  2020-08-03     1  115.0
# 23   Vegas Golden Knights  2020-08-03     0 -115.0

# %%
pl_df = pl_api(pl_response)

# %%
pl_df
# Out:
#                      Team        Date  Home Puck Line    PL
# 0     Carolina Hurricanes  2020-08-01     1     -1.50   187
# 1        New York Rangers  2020-08-01     0      1.50  -225
# 2      Chicago Blackhawks  2020-08-01     1      1.50  -188
# 3         Edmonton Oilers  2020-08-01     0     -1.50   163
# 4        Florida Panthers  2020-08-01     1      1.50  -253
# 5      New York Islanders  2020-08-01     0     -1.50   211
# 6      Montreal Canadiens  2020-08-01     1       NaN   NaN
# 7     Pittsburgh Penguins  2020-08-01     0       NaN   NaN
# 8          Calgary Flames  2020-08-01     1     -1.50   207
# 9           Winnipeg Jets  2020-08-01     0      1.50  -252
# 10        Arizona Coyotes  2020-08-02     1      1.50  -236
# 11    Nashville Predators  2020-08-02     0     -1.50   197
# 12          Boston Bruins  2020-08-02     1     -1.50   139
# 13    Philadelphia Flyers  2020-08-02     0      1.50  -293
# 14     Colorado Avalanche  2020-08-02     1       NaN   NaN
# 15         St Louis Blues  2020-08-02     0       NaN   NaN
# 16  Columbus Blue Jackets  2020-08-02     1      1.50  -188
# 17    Toronto Maple Leafs  2020-08-02     0     -1.50   163
# 18         Minnesota Wild  2020-08-02     1      1.50  -239
# 19      Vancouver Canucks  2020-08-02     0     -1.50   197
# 20    Tampa Bay Lightning  2020-08-03     1      -1.5   183
# 21    Washington Capitals  2020-08-03     0       1.5  -226
# 22           Dallas Stars  2020-08-03     1       1.5  -239
# 23   Vegas Golden Knights  2020-08-03     0      -1.5   195

# %%
ml_df.to_csv('ml_input.csv')

# %%
pl_df.to_csv('pl_input.csv')
