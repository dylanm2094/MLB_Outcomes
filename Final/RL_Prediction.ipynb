# %%
import pandas as pd
from keras.models import Sequential, model_from_json
from keras.layers import Dense
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
import keras
# Out:
# Using TensorFlow backend.

# %%
df = pd.read_csv("raw_input.csv")
df
# Out:
#    home  season_hits_for  season_hits_against  season_runs_for  \
# 0     1              240                  288               96
# 1     0              220                  256              110
# 2     0              260                  246              137
# 3     0              306                  205              190
# 4     1              230                  262              108
# 5     0              285                  279              130
# 6     1              238                  231              119
# 7     1              251                  285              129
# 8     0              289                  239              154
# 9     0              333                  281              144
#
#    season_runs_against  season_errors  season_wins  ml_odds  rl_odds
# 0                  163             27            7     -105     -170
# 1                  178             23            7     -105      150
# 2                  119             19           18     -140      120
# 3                   89             19           21      116     -185
# 4                  120             10           15     -107      180
# 5                  141             16           15     -103     -210
# 6                   97             12           19      125     -140
# 7                  153             21           13     -115      170
# 8                  137             20           16      130     -165
# 9                  137             22           18     -108      156

# %%
def load_model():
    # loading model
    model = model_from_json(open('rl_model_architecture.json').read())
    model.load_weights('rl_model_weights.h5')
    model.compile(loss='categorical_crossentropy', optimizer='adam')
    return model

# %%
# load
model = load_model()

# predictions
predictions = model.predict_classes(df, verbose=2)
print(predictions)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-5f801d72c22a> in <module>
#       1 # load
# ----> 2 model = load_model()
#       3
#       4 # predictions
#       5 predictions = model.predict_classes(df, verbose=2)
#
# <ipython-input-3-8b12e1167c4b> in load_model()
#       1 def load_model():
#       2     # loading model
# ----> 3     model = model_from_json(open('rl_model_architecture.json').read())
#       4     model.load_weights('rl_model_weights.h5')
#       5     model.compile(loss='categorical_crossentropy', optimizer='adam')
#
# /opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages/keras/engine/saving.py in model_from_json(json_string, custom_objects)
#     662     config = json.loads(json_string)
#     663     from ..layers import deserialize
# --> 664     return deserialize(config, custom_objects=custom_objects)
#     665
#     666
#
# /opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages/keras/layers/__init__.py in deserialize(config, custom_objects)
#     166                                     module_objects=globs,
#     167                                     custom_objects=custom_objects,
# --> 168                                     printable_module_name='layer')
#
# /opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages/keras/utils/generic_utils.py in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     145                     config['config'],
#     146                     custom_objects=dict(list(_GLOBAL_CUSTOM_OBJECTS.items()) +
# --> 147                                         list(custom_objects.items())))
#     148             with CustomObjectScope(custom_objects):
#     149                 return cls.from_config(config['config'])
#
# /opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages/keras/engine/sequential.py in from_config(cls, config, custom_objects)
#     299         for conf in layer_configs:
#     300             layer = layer_module.deserialize(conf,
# --> 301                                              custom_objects=custom_objects)
#     302             model.add(layer)
#     303         if not model.inputs and build_input_shape:
#
# /opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages/keras/layers/__init__.py in deserialize(config, custom_objects)
#     166                                     module_objects=globs,
#     167                                     custom_objects=custom_objects,
# --> 168                                     printable_module_name='layer')
#
# /opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages/keras/utils/generic_utils.py in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     147                                         list(custom_objects.items())))
#     148             with CustomObjectScope(custom_objects):
# --> 149                 return cls.from_config(config['config'])
#     150         else:
#     151             # Then `cls` may be a function returning a class.
#
# /opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages/keras/engine/base_layer.py in from_config(cls, config)
#    1177             A layer instance.
#    1178         """
# -> 1179         return cls(**config)
#    1180
#    1181     def count_params(self):
#
# /opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# /opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages/keras/layers/core.py in __init__(self, units, activation, use_bias, kernel_initializer, bias_initializer, kernel_regularizer, bias_regularizer, activity_regularizer, kernel_constraint, bias_constraint, **kwargs)
#     875         self.activation = activations.get(activation)
#     876         self.use_bias = use_bias
# --> 877         self.kernel_initializer = initializers.get(kernel_initializer)
#     878         self.bias_initializer = initializers.get(bias_initializer)
#     879         self.kernel_regularizer = regularizers.get(kernel_regularizer)
#
# /opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages/keras/initializers.py in get(identifier)
#     513 def get(identifier):
#     514     if isinstance(identifier, dict):
# --> 515         return deserialize(identifier)
#     516     elif isinstance(identifier, six.string_types):
#     517         config = {'class_name': str(identifier), 'config': {}}
#
# /opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages/keras/initializers.py in deserialize(config, custom_objects)
#     508                                     module_objects=globals(),
#     509                                     custom_objects=custom_objects,
# --> 510                                     printable_module_name='initializer')
#     511
#     512
#
# /opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages/keras/utils/generic_utils.py in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     138             if cls is None:
#     139                 raise ValueError('Unknown ' + printable_module_name +
# --> 140                                  ': ' + class_name)
#     141         if hasattr(cls, 'from_config'):
#     142             custom_objects = custom_objects or {}
#
# ValueError: Unknown initializer: GlorotUniform
